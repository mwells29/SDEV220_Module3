# %%
#7.4 
things = ["mozzarella", "cinderella", "salmonella"]

# %%
#7.5
print(things[1].capitalize())
print(things)
# Out:
# Cinderella
# ['mozzarella', 'cinderella', 'salmonella']

# %%
#it did not change the element in the list

# %%
#7.6
print(things[0].capitalize())
# Out:
# Mozzarella

# %%
#7.7
del things[-1]
print(things)
# Out:
# ['mozzarella', 'cinderella']

# %%
#9.1
def good():
    ['Harry', 'Ron', 'Hermione']

# %%
#9.2
def get_odds():
      for num in range(10):
       if num % 2:
        yield num

number = 0
for count in get_odds():
          number += 1
          if number == 3:
              print(count)
              break
# Out:
# 5
